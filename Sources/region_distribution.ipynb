# %%
import pandas as pd
import make_map # make_map.py

# %%
# 관광지 데이터의 값들을 미리 나눠둔 구역별로 분할한 후 csv로 저장
# 지도 출력을 위해 구역에 맞게 새롭게 분할한 데이터프레임을 반환함
def distribution(input_file, output_file, region_list):
    # 파일 불러오기
    df = pd.read_csv(input_file, encoding="cp949")
    jeju_n_list = region_list # 제주 구역별 행정동 리스트 
    jeju_df = pd.DataFrame(columns=df.columns) # 데이터프레임 생성
    
    # road_address(도로명주소 컬럼)에서 제주 구역별 행정동이 포함된 데이터 찾기
    for i in jeju_n_list:
        contain = df[df['road_address'].str.contains(i)]
        jeju_df = pd.concat([jeju_df, contain], ignore_index=True)
        
    # 구역에 맞게 분할한 데이터를 csv파일로 저장
    jeju_df.to_csv(output_file, encoding="cp949", index=False)
    
    return jeju_df

# %%
# 1, 3구역에서  2, 4구역과 겹치는 부분을 제외한 후 분할해서 csv로 저장
# 지도 출력을 위해 구역에 맞게 새롭게 분할한 데이터프레임을 반환함
def distribution_remove(input_file, output_file, contain_region, not_contain_list):
    # 파일 불러오기
    df = pd.read_csv(input_file, encoding="cp949")
    contain_list = contain_region # 포함시킬 부분 (제주시 / 서귀포시)
    not_contain_list = not_contain_list # 2,4구역과 겹치는 부분(제외시킬 부분)
    
    jeju_df = pd.DataFrame(columns=df.columns)
    
    # contain_region에 해당하는 데이터 추출
    for region in contain_list:
        contain = df[df['road_address'].str.contains(region)]
        jeju_df = pd.concat([jeju_df, contain])

    # not_contain_list에 해당하는 데이터 제외
    for not_contain_region in not_contain_list:
        jeju_df = jeju_df[~jeju_df['road_address'].str.contains(not_contain_region)]
    
    # 구역에 맞게 분할한 데이터를 csv파일로 저장
    jeju_df.reset_index(drop=True, inplace=True)
    jeju_df.to_csv(output_file, encoding="cp949", index=False)
    
    return jeju_df

# %%
# 1구역 - 제주시
# 2,4구역 일부가 제주시에 속하므로 겹칠 수 있기 때문에 2,4구역은 제외해줌

jeju1_contain = ["제주시"]
jeju1_not_contain = ['애월읍', '한림읍', '한경면', '대정읍', '안덕면', 
                     '조천읍', '구좌읍', '남원읍', '표선면', '성산읍', '구좌읍', '우도면'] 

jeju1_tour_df = distribution_remove('tour_region.csv',
                                  'jeju1_tour_region.csv', 
                                  jeju1_contain,
                                  jeju1_not_contain)

jeju1_cf_souv_df = distribution_remove('tour_cafe_souvenir.csv',
                                  'jeju1_cafe_souvenir.csv', 
                                  jeju1_contain,
                                  jeju1_not_contain)

jeju1_restr_df = distribution_remove('tour_restaurant.csv',
                                  'jeju1_restaurant.csv', 
                                  jeju1_contain,
                                  jeju1_not_contain)

# %%
make_map.make_map(jeju1_tour_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ebbddd0bb482eb8e1c219f192b3e034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ebbddd0bb482eb8e1c219f192b3e034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ebbddd0bb482eb8e1c219f192b3e034 = L.map(
#                 &quot;map_2ebbddd0bb482eb8e1c219f192b3e034&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fcd199dac66d0603b2807191f07f53c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4fcd199dac66d0603b2807191f07f53c.addTo(map_2ebbddd0bb482eb8e1c219f192b3e034);
#
#             var tile_layer_c70c7c978d96fe20ea0d513e4cd1a7bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_dce4b6a3ee01c861a93b9f94cdbebb19 = new L.Control.MiniMap(
#                 tile_layer_c70c7c978d96fe20ea0d513e4cd1a7bc,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_2ebbddd0bb482eb8e1c219f192b3e034.addControl(mini_map_dce4b6a3ee01c861a93b9f94cdbebb19);
#
#
#             var marker_799f21cc8c3165edbc2302fba7a3e168 = L.marker(
#                 [33.45854604, 126.48529],
#                 {}
#             ).addTo(map_2ebbddd0bb482eb8e1c219f192b3e034);
#
#
#         var popup_a0c75b9fa84df6c406767d77e93bce20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14a16f0db0489538134311dda0920331 = $(`&lt;div id=&quot;html_14a16f0db0489538134311dda0920331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/1826295011&lt;/div&gt;`)[0];
#                 popup_a0c75b9fa84df6c406767d77e93bce20.setContent(html_14a16f0db0489538134311dda0920331);
#
#
#
#         marker_799f21cc8c3165edbc2302fba7a3e168.bindPopup(popup_a0c75b9fa84df6c406767d77e93bce20)
#         ;
#
#
#
#
#             marker_799f21cc8c3165edbc2302fba7a3e168.bindTooltip(
#                 `&lt;div&gt;
#                      브릭캠퍼스 제주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd3634a327f05a3d2d33152fae981af8 = L.marker(
#                 [33.43236108, 126.5977721],
#                 {}
#             ).addTo(map_2ebbddd0bb482eb8e1c219f192b3e034);
#
#
#         var popup_ab2f73823fc694296879e501796d180f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa320da986d5f93c49c7c8f2cac78e60 = $(`&lt;div id=&quot;html_fa320da986d5f93c49c7c8f2cac78e60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/17583340&lt;/div&gt;`)[0];
#                 popup_ab2f73823fc694296879e501796d180f.setContent(html_fa320da986d5f93c49c7c8f2cac78e60);
#
#
#
#         marker_dd3634a327f05a3d2d33152fae981af8.bindPopup(popup_ab2f73823fc694296879e501796d180f)
#         ;
#
#
#
#
#             marker_dd3634a327f05a3d2d33152fae981af8.bindTooltip(
#                 `&lt;div&gt;
#                      한라생태숲 수생식물원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_45227b6fb89b04d6ed2ea752b1fa0912 = L.marker(
#                 [33.48069526, 126.4946497],
#                 {}
#             ).addTo(map_2ebbddd0bb482eb8e1c219f192b3e034);
#
#
#         var popup_b0a94b885f7a07d8185666dd5419431c = L.popup({&quot;maxWidt

# %%
make_map.make_map(jeju1_cf_souv_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0806aabaa97849d982ef94e9f02e0d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0806aabaa97849d982ef94e9f02e0d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0806aabaa97849d982ef94e9f02e0d5 = L.map(
#                 &quot;map_e0806aabaa97849d982ef94e9f02e0d5&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d22ae8298edffff86e2e35dba559802 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_1d22ae8298edffff86e2e35dba559802.addTo(map_e0806aabaa97849d982ef94e9f02e0d5);
#
#             var tile_layer_c540a79473bd67063857cfcbf6ec4e7a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_f690fb6c4106a9a41877228146e2fd71 = new L.Control.MiniMap(
#                 tile_layer_c540a79473bd67063857cfcbf6ec4e7a,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_e0806aabaa97849d982ef94e9f02e0d5.addControl(mini_map_f690fb6c4106a9a41877228146e2fd71);
#
#
#             var marker_fb7c694448911f6da106f0255f721185 = L.marker(
#                 [33.44994698, 126.4875563],
#                 {}
#             ).addTo(map_e0806aabaa97849d982ef94e9f02e0d5);
#
#
#         var popup_f8edb0e4edf5232e8ed27d4196e465b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acee4425711a6ce4548e8e5bb7ba46b2 = $(`&lt;div id=&quot;html_acee4425711a6ce4548e8e5bb7ba46b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/263044374&lt;/div&gt;`)[0];
#                 popup_f8edb0e4edf5232e8ed27d4196e465b0.setContent(html_acee4425711a6ce4548e8e5bb7ba46b2);
#
#
#
#         marker_fb7c694448911f6da106f0255f721185.bindPopup(popup_f8edb0e4edf5232e8ed27d4196e465b0)
#         ;
#
#
#
#
#             marker_fb7c694448911f6da106f0255f721185.bindTooltip(
#                 `&lt;div&gt;
#                      미스틱3도
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1d55c1c16cdd92848c6f6fa833b68ff5 = L.marker(
#                 [33.50407967, 126.5392353],
#                 {}
#             ).addTo(map_e0806aabaa97849d982ef94e9f02e0d5);
#
#
#         var popup_f6babafcb77c687f8e2d4ab821f0ba21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e841805b1cddc8ead88597a37f5cae71 = $(`&lt;div id=&quot;html_e841805b1cddc8ead88597a37f5cae71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/1613900075&lt;/div&gt;`)[0];
#                 popup_f6babafcb77c687f8e2d4ab821f0ba21.setContent(html_e841805b1cddc8ead88597a37f5cae71);
#
#
#
#         marker_1d55c1c16cdd92848c6f6fa833b68ff5.bindPopup(popup_f6babafcb77c687f8e2d4ab821f0ba21)
#         ;
#
#
#
#
#             marker_1d55c1c16cdd92848c6f6fa833b68ff5.bindTooltip(
#                 `&lt;div&gt;
#                      제주바솔트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b65434d6ffe61d9845818fc20f7009d7 = L.marker(
#                 [33.51216801, 126.5395218],
#                 {}
#             ).addTo(map_e0806aabaa97849d982ef94e9f02e0d5);
#
#
#         var popup_817f2607a6c8b132cdb7802610a41872 = L.popup({&quot;maxWidth&quot

# %%
make_map.make_map(jeju1_restr_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_373bf5ef2a7b1dac343707084ddb19c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_373bf5ef2a7b1dac343707084ddb19c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_373bf5ef2a7b1dac343707084ddb19c0 = L.map(
#                 &quot;map_373bf5ef2a7b1dac343707084ddb19c0&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e311e26d9758b969e3ec8c07650cf75c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_e311e26d9758b969e3ec8c07650cf75c.addTo(map_373bf5ef2a7b1dac343707084ddb19c0);
#
#             var tile_layer_5d9d03d1c24db8c0d70e242ef5c1fef9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_4952fbdc2836cfaf72be40ab89838148 = new L.Control.MiniMap(
#                 tile_layer_5d9d03d1c24db8c0d70e242ef5c1fef9,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_373bf5ef2a7b1dac343707084ddb19c0.addControl(mini_map_4952fbdc2836cfaf72be40ab89838148);
#
#
#             var marker_b12ca7bc942ee51c42e10beeec7f24f4 = L.marker(
#                 [33.50852103, 126.540725],
#                 {}
#             ).addTo(map_373bf5ef2a7b1dac343707084ddb19c0);
#
#
#         var popup_a80e17ea674249bdf6f50f693e9eae3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a1e032844ba314a786087b24b3eb9e3 = $(`&lt;div id=&quot;html_2a1e032844ba314a786087b24b3eb9e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/21499653&lt;/div&gt;`)[0];
#                 popup_a80e17ea674249bdf6f50f693e9eae3c.setContent(html_2a1e032844ba314a786087b24b3eb9e3);
#
#
#
#         marker_b12ca7bc942ee51c42e10beeec7f24f4.bindPopup(popup_a80e17ea674249bdf6f50f693e9eae3c)
#         ;
#
#
#
#
#             marker_b12ca7bc942ee51c42e10beeec7f24f4.bindTooltip(
#                 `&lt;div&gt;
#                      은희네해장국 본점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b39c1a685fa6941ebf451b247f7bc3d2 = L.marker(
#                 [33.50541905, 126.5415615],
#                 {}
#             ).addTo(map_373bf5ef2a7b1dac343707084ddb19c0);
#
#
#         var popup_d766580b5357625cd112dad282718d41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f31b618ba3093a1fa6bc15acd57e0b2 = $(`&lt;div id=&quot;html_5f31b618ba3093a1fa6bc15acd57e0b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/7972099&lt;/div&gt;`)[0];
#                 popup_d766580b5357625cd112dad282718d41.setContent(html_5f31b618ba3093a1fa6bc15acd57e0b2);
#
#
#
#         marker_b39c1a685fa6941ebf451b247f7bc3d2.bindPopup(popup_d766580b5357625cd112dad282718d41)
#         ;
#
#
#
#
#             marker_b39c1a685fa6941ebf451b247f7bc3d2.bindTooltip(
#                 `&lt;div&gt;
#                      신설오름
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b489f0b924521fd8d08bb488be83a19e = L.marker(
#                 [33.49152862, 126.4972672],
#                 {}
#             ).addTo(map_373bf5ef2a7b1dac343707084ddb19c0);
#
#
#         var popup_bb1bf658b60f730fc948f644c57c7657 = L.popup({&quot;maxWidth&quot;:

# %%
# 2구역 - 제주서부
jeju2 = ['애월읍', '한림읍', '한경면', '대정읍', '안덕면'] 

# 관광지
jeju2_tour_df = distribution("tour_region.csv",
                            "jeju2_tour_region.csv",
                            jeju2)

# 카페/기념품
jeju2_cf_souv_df = distribution("tour_cafe_souvenir.csv",
                       "jeju2_cafe_souvenir.csv",
                       jeju2)

# 음식점
jeju2_restr_df = distribution("tour_restaurant.csv",
                       "jeju2_restaurant.csv",
                       jeju2)

# %%
# 지도 표출 함수 호출
make_map.make_map(jeju2_tour_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06f291de92b826d3ab1041ba8d2a6357 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06f291de92b826d3ab1041ba8d2a6357&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06f291de92b826d3ab1041ba8d2a6357 = L.map(
#                 &quot;map_06f291de92b826d3ab1041ba8d2a6357&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_542f718a7b7e7594d4c082e3a95a99af = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_542f718a7b7e7594d4c082e3a95a99af.addTo(map_06f291de92b826d3ab1041ba8d2a6357);
#
#             var tile_layer_3108bf2262e6aa983e2432620844c21e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_c59e57125951d740ca0a18ad72d35248 = new L.Control.MiniMap(
#                 tile_layer_3108bf2262e6aa983e2432620844c21e,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_06f291de92b826d3ab1041ba8d2a6357.addControl(mini_map_c59e57125951d740ca0a18ad72d35248);
#
#
#             var marker_3161fe1bbcabdf0ae0cfa54a91d99234 = L.marker(
#                 [33.4506404, 126.3046776],
#                 {}
#             ).addTo(map_06f291de92b826d3ab1041ba8d2a6357);
#
#
#         var popup_9c0d0c81f07ad45479b67ac4f31d167c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f94c7deb12a370bd86fd5e262a63b48 = $(`&lt;div id=&quot;html_2f94c7deb12a370bd86fd5e262a63b48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/25022153&lt;/div&gt;`)[0];
#                 popup_9c0d0c81f07ad45479b67ac4f31d167c.setContent(html_2f94c7deb12a370bd86fd5e262a63b48);
#
#
#
#         marker_3161fe1bbcabdf0ae0cfa54a91d99234.bindPopup(popup_9c0d0c81f07ad45479b67ac4f31d167c)
#         ;
#
#
#
#
#             marker_3161fe1bbcabdf0ae0cfa54a91d99234.bindTooltip(
#                 `&lt;div&gt;
#                      곽지해수욕장
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be49399a67aee6f594f2ec73e8439eff = L.marker(
#                 [33.36627759, 126.3577307],
#                 {}
#             ).addTo(map_06f291de92b826d3ab1041ba8d2a6357);
#
#
#         var popup_4f2bfc85873889f500494a228465e129 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8814507b2366a5326f5f796b4e3a2a85 = $(`&lt;div id=&quot;html_8814507b2366a5326f5f796b4e3a2a85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/25274725&lt;/div&gt;`)[0];
#                 popup_4f2bfc85873889f500494a228465e129.setContent(html_8814507b2366a5326f5f796b4e3a2a85);
#
#
#
#         marker_be49399a67aee6f594f2ec73e8439eff.bindPopup(popup_4f2bfc85873889f500494a228465e129)
#         ;
#
#
#
#
#             marker_be49399a67aee6f594f2ec73e8439eff.bindTooltip(
#                 `&lt;div&gt;
#                      새별오름
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8538471bd7d6f2c5b937390242481381 = L.marker(
#                 [33.47619484, 126.3569359],
#                 {}
#             ).addTo(map_06f291de92b826d3ab1041ba8d2a6357);
#
#
#         var popup_7062bf50fe0cba3c2522bfd4c4230fbd = L.popup({&quot;maxWidth&quot;: &

# %%
make_map.make_map(jeju2_cf_souv_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0906d0b7bd2e27f0ebc01d679e14a59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0906d0b7bd2e27f0ebc01d679e14a59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0906d0b7bd2e27f0ebc01d679e14a59 = L.map(
#                 &quot;map_c0906d0b7bd2e27f0ebc01d679e14a59&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bc80773ef78a178c88e98a662e0da4a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_6bc80773ef78a178c88e98a662e0da4a.addTo(map_c0906d0b7bd2e27f0ebc01d679e14a59);
#
#             var tile_layer_2c3d419c92fd356251ab4f22bfb8f235 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_0873d28d2ec962d3c8bcd46569bb6539 = new L.Control.MiniMap(
#                 tile_layer_2c3d419c92fd356251ab4f22bfb8f235,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_c0906d0b7bd2e27f0ebc01d679e14a59.addControl(mini_map_0873d28d2ec962d3c8bcd46569bb6539);
#
#
#             var marker_db27ff72a345fcf7b7b34fc9d98c0d10 = L.marker(
#                 [33.44827816, 126.3016141],
#                 {}
#             ).addTo(map_c0906d0b7bd2e27f0ebc01d679e14a59);
#
#
#         var popup_c1780688dd081083610a433ea50d8cdd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9269d78c2e5dfecb01b89ce64dc1da7 = $(`&lt;div id=&quot;html_e9269d78c2e5dfecb01b89ce64dc1da7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/788872329&lt;/div&gt;`)[0];
#                 popup_c1780688dd081083610a433ea50d8cdd.setContent(html_e9269d78c2e5dfecb01b89ce64dc1da7);
#
#
#
#         marker_db27ff72a345fcf7b7b34fc9d98c0d10.bindPopup(popup_c1780688dd081083610a433ea50d8cdd)
#         ;
#
#
#
#
#             marker_db27ff72a345fcf7b7b34fc9d98c0d10.bindTooltip(
#                 `&lt;div&gt;
#                      애월빵공장앤카페
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b631d77a099f1e86d2aab665328ab196 = L.marker(
#                 [33.41894364, 126.3113672],
#                 {}
#             ).addTo(map_c0906d0b7bd2e27f0ebc01d679e14a59);
#
#
#         var popup_db365cd5047f9ecf521b38d8aea72b4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71a1b358a40ebbfe2472dc3004068fa5 = $(`&lt;div id=&quot;html_71a1b358a40ebbfe2472dc3004068fa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/378536424&lt;/div&gt;`)[0];
#                 popup_db365cd5047f9ecf521b38d8aea72b4f.setContent(html_71a1b358a40ebbfe2472dc3004068fa5);
#
#
#
#         marker_b631d77a099f1e86d2aab665328ab196.bindPopup(popup_db365cd5047f9ecf521b38d8aea72b4f)
#         ;
#
#
#
#
#             marker_b631d77a099f1e86d2aab665328ab196.bindTooltip(
#                 `&lt;div&gt;
#                      무무제주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9c0eab78bcf9f825032f35a8985536a = L.marker(
#                 [33.46253453, 126.3120263],
#                 {}
#             ).addTo(map_c0906d0b7bd2e27f0ebc01d679e14a59);
#
#
#         var popup_e3621b8baf9bbbdc80b6e67606221274 = L.popup({&quot;maxWidth&quo

# %%
make_map.make_map(jeju2_restr_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_339346767c9921581d681780272d90cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_339346767c9921581d681780272d90cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_339346767c9921581d681780272d90cf = L.map(
#                 &quot;map_339346767c9921581d681780272d90cf&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89f4c2d56018aefba37b000675ec4e32 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_89f4c2d56018aefba37b000675ec4e32.addTo(map_339346767c9921581d681780272d90cf);
#
#             var tile_layer_f02adff73caee6b0855d51a460e31668 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_51e57433537020eb0e52e04a68f9cfb1 = new L.Control.MiniMap(
#                 tile_layer_f02adff73caee6b0855d51a460e31668,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_339346767c9921581d681780272d90cf.addControl(mini_map_51e57433537020eb0e52e04a68f9cfb1);
#
#
#             var marker_12f65a26ab6ee4ac521dffc88ae517ec = L.marker(
#                 [33.48580465, 126.3924578],
#                 {}
#             ).addTo(map_339346767c9921581d681780272d90cf);
#
#
#         var popup_35df69344342bbc789cf68eb8af2c512 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_204079c6c9a702f49b4f7c5b9a643cbb = $(`&lt;div id=&quot;html_204079c6c9a702f49b4f7c5b9a643cbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/879542502&lt;/div&gt;`)[0];
#                 popup_35df69344342bbc789cf68eb8af2c512.setContent(html_204079c6c9a702f49b4f7c5b9a643cbb);
#
#
#
#         marker_12f65a26ab6ee4ac521dffc88ae517ec.bindPopup(popup_35df69344342bbc789cf68eb8af2c512)
#         ;
#
#
#
#
#             marker_12f65a26ab6ee4ac521dffc88ae517ec.bindTooltip(
#                 `&lt;div&gt;
#                      문개항아리 애월점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd8740093baac90c7e60564bffb53dd7 = L.marker(
#                 [33.46569614, 126.3342728],
#                 {}
#             ).addTo(map_339346767c9921581d681780272d90cf);
#
#
#         var popup_bd5effb921e86467a1679789ea997b13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43adc061069128d465fb048d78c46126 = $(`&lt;div id=&quot;html_43adc061069128d465fb048d78c46126&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/26463066&lt;/div&gt;`)[0];
#                 popup_bd5effb921e86467a1679789ea997b13.setContent(html_43adc061069128d465fb048d78c46126);
#
#
#
#         marker_dd8740093baac90c7e60564bffb53dd7.bindPopup(popup_bd5effb921e86467a1679789ea997b13)
#         ;
#
#
#
#
#             marker_dd8740093baac90c7e60564bffb53dd7.bindTooltip(
#                 `&lt;div&gt;
#                      마틸다
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3990ec3ea9e3b9c4090afd5537c280d0 = L.marker(
#                 [33.47249733, 126.3484558],
#                 {}
#             ).addTo(map_339346767c9921581d681780272d90cf);
#
#
#         var popup_c0f40ab79a70d477e64840f99348859a = L.popup({&quot;maxWidth&quot

# %%
# 3구역 - 서귀포시
# 2,4구역 일부가 서귀포시에 속하므로 겹칠 수 있기 때문에 2,4구역은 제외해줌

jeju3_contain = ["서귀포시"]
jeju3_not_contain = ['애월읍', '한림읍', '한경면', '대정읍', '안덕면', 
                     '조천읍', '구좌읍', '남원읍', '표선면', '성산읍', '구좌읍', '우도면'] 

jeju3_tour_df = distribution_remove('tour_region.csv',
                                  'jeju3_tour_region.csv', 
                                  jeju3_contain,
                                  jeju3_not_contain)

jeju3_cf_souv_df = distribution_remove('tour_cafe_souvenir.csv',
                                  'jeju3_cafe_souvenir.csv', 
                                  jeju3_contain,
                                  jeju3_not_contain)

jeju3_restr_df = distribution_remove('tour_restaurant.csv',
                                  'jeju3_restaurant.csv', 
                                  jeju3_contain,
                                  jeju3_not_contain)

# %%
# 지도 표출 함수 호출
make_map.make_map(jeju3_tour_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98b4b0db798557b9844f962fa7cb3a53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98b4b0db798557b9844f962fa7cb3a53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98b4b0db798557b9844f962fa7cb3a53 = L.map(
#                 &quot;map_98b4b0db798557b9844f962fa7cb3a53&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc76563454edb0edc50e40ac95cf6dda = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_cc76563454edb0edc50e40ac95cf6dda.addTo(map_98b4b0db798557b9844f962fa7cb3a53);
#
#             var tile_layer_dcf043a6693659ed2e920fa42c26b9f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_b34b4bea9b95ca1db3a942f97632530c = new L.Control.MiniMap(
#                 tile_layer_dcf043a6693659ed2e920fa42c26b9f3,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_98b4b0db798557b9844f962fa7cb3a53.addControl(mini_map_b34b4bea9b95ca1db3a942f97632530c);
#
#
#             var marker_c1332d538b2f2aa3806820a9788f77f6 = L.marker(
#                 [33.24688674, 126.5115155],
#                 {}
#             ).addTo(map_98b4b0db798557b9844f962fa7cb3a53);
#
#
#         var popup_7b48b618ea2645400379acad121175c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3de13f078340c8b5429c42fba466e812 = $(`&lt;div id=&quot;html_3de13f078340c8b5429c42fba466e812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/11126147&lt;/div&gt;`)[0];
#                 popup_7b48b618ea2645400379acad121175c6.setContent(html_3de13f078340c8b5429c42fba466e812);
#
#
#
#         marker_c1332d538b2f2aa3806820a9788f77f6.bindPopup(popup_7b48b618ea2645400379acad121175c6)
#         ;
#
#
#
#
#             marker_c1332d538b2f2aa3806820a9788f77f6.bindTooltip(
#                 `&lt;div&gt;
#                      세리월드 카트레이싱
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7bc4d24b40269730a261f5c68f9cc6ec = L.marker(
#                 [33.24701618, 126.5118743],
#                 {}
#             ).addTo(map_98b4b0db798557b9844f962fa7cb3a53);
#
#
#         var popup_07c676c8a7d6ccddd1eba5be698062d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a7ce18b2b5fae839306b1159d3ca00d = $(`&lt;div id=&quot;html_0a7ce18b2b5fae839306b1159d3ca00d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/10472331&lt;/div&gt;`)[0];
#                 popup_07c676c8a7d6ccddd1eba5be698062d6.setContent(html_0a7ce18b2b5fae839306b1159d3ca00d);
#
#
#
#         marker_7bc4d24b40269730a261f5c68f9cc6ec.bindPopup(popup_07c676c8a7d6ccddd1eba5be698062d6)
#         ;
#
#
#
#
#             marker_7bc4d24b40269730a261f5c68f9cc6ec.bindTooltip(
#                 `&lt;div&gt;
#                      세리월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_704a385783c2ffb5f8e137de072aa31b = L.marker(
#                 [33.2365614, 126.5976625],
#                 {}
#             ).addTo(map_98b4b0db798557b9844f962fa7cb3a53);
#
#
#         var popup_b195d2a70b62d0ae1dea68dddadfff94 = L.popup({&quot;maxWidth&quot

# %%
make_map.make_map(jeju3_cf_souv_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b23d146c781d380d0091eabcc658dc8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b23d146c781d380d0091eabcc658dc8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b23d146c781d380d0091eabcc658dc8e = L.map(
#                 &quot;map_b23d146c781d380d0091eabcc658dc8e&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b5916051b75f728015597c64c0c75c5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3b5916051b75f728015597c64c0c75c5.addTo(map_b23d146c781d380d0091eabcc658dc8e);
#
#             var tile_layer_f1b6fdc3052ae3a68e1c0ad57027f73f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_b8bc9fcd83321614a254c9887923025f = new L.Control.MiniMap(
#                 tile_layer_f1b6fdc3052ae3a68e1c0ad57027f73f,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_b23d146c781d380d0091eabcc658dc8e.addControl(mini_map_b8bc9fcd83321614a254c9887923025f);
#
#
#             var marker_999026c3e39b1b3c695ab69b1aa94eb3 = L.marker(
#                 [33.24292106, 126.5546621],
#                 {}
#             ).addTo(map_b23d146c781d380d0091eabcc658dc8e);
#
#
#         var popup_be236e21ec5561b25a8a33a70e45a183 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b21c193af5e69370be4ab4829e8eb335 = $(`&lt;div id=&quot;html_b21c193af5e69370be4ab4829e8eb335&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/1028406499&lt;/div&gt;`)[0];
#                 popup_be236e21ec5561b25a8a33a70e45a183.setContent(html_b21c193af5e69370be4ab4829e8eb335);
#
#
#
#         marker_999026c3e39b1b3c695ab69b1aa94eb3.bindPopup(popup_be236e21ec5561b25a8a33a70e45a183)
#         ;
#
#
#
#
#             marker_999026c3e39b1b3c695ab69b1aa94eb3.bindTooltip(
#                 `&lt;div&gt;
#                      꽃이피다앤블라썸
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_625cff97f1e020b439aee520626446b0 = L.marker(
#                 [33.23690685, 126.436715],
#                 {}
#             ).addTo(map_b23d146c781d380d0091eabcc658dc8e);
#
#
#         var popup_87efb9936a6cbf90cb2f6e5179c2bab0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42009b42620a17f89159331160f9237b = $(`&lt;div id=&quot;html_42009b42620a17f89159331160f9237b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/1983315941&lt;/div&gt;`)[0];
#                 popup_87efb9936a6cbf90cb2f6e5179c2bab0.setContent(html_42009b42620a17f89159331160f9237b);
#
#
#
#         marker_625cff97f1e020b439aee520626446b0.bindPopup(popup_87efb9936a6cbf90cb2f6e5179c2bab0)
#         ;
#
#
#
#
#             marker_625cff97f1e020b439aee520626446b0.bindTooltip(
#                 `&lt;div&gt;
#                      바다다
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a61ee87bd6c6f6fd83f48414d19a7c4e = L.marker(
#                 [33.23609313, 126.5149177],
#                 {}
#             ).addTo(map_b23d146c781d380d0091eabcc658dc8e);
#
#
#         var popup_15b9e8d54714e69b8998b81a6647e0a2 = L.popup({&quot;maxWidth&quo

# %%
make_map.make_map(jeju3_restr_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67dc5a1e04d7d5e7bdc45fcbdaea8c41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67dc5a1e04d7d5e7bdc45fcbdaea8c41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67dc5a1e04d7d5e7bdc45fcbdaea8c41 = L.map(
#                 &quot;map_67dc5a1e04d7d5e7bdc45fcbdaea8c41&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb94b3f8403812ff33a9ac202947587d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_fb94b3f8403812ff33a9ac202947587d.addTo(map_67dc5a1e04d7d5e7bdc45fcbdaea8c41);
#
#             var tile_layer_c3daf6aff730cff34ca27076334796cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_d6d03c952f751940c7eee72850ec4bea = new L.Control.MiniMap(
#                 tile_layer_c3daf6aff730cff34ca27076334796cb,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_67dc5a1e04d7d5e7bdc45fcbdaea8c41.addControl(mini_map_d6d03c952f751940c7eee72850ec4bea);
#
#
#             var marker_6231b9abf8c5253f76c45ada03a407da = L.marker(
#                 [33.26047394, 126.5821867],
#                 {}
#             ).addTo(map_67dc5a1e04d7d5e7bdc45fcbdaea8c41);
#
#
#         var popup_04f5e5914a99b2d9c967753c319bec82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e42a5f74b3d70eb3e9c9db50f91ea7d = $(`&lt;div id=&quot;html_5e42a5f74b3d70eb3e9c9db50f91ea7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/24839178&lt;/div&gt;`)[0];
#                 popup_04f5e5914a99b2d9c967753c319bec82.setContent(html_5e42a5f74b3d70eb3e9c9db50f91ea7d);
#
#
#
#         marker_6231b9abf8c5253f76c45ada03a407da.bindPopup(popup_04f5e5914a99b2d9c967753c319bec82)
#         ;
#
#
#
#
#             marker_6231b9abf8c5253f76c45ada03a407da.bindTooltip(
#                 `&lt;div&gt;
#                      은희네해장국 서귀포점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9a56d1cbda89f86ee95b6ee433e4dc7 = L.marker(
#                 [33.23690685, 126.436715],
#                 {}
#             ).addTo(map_67dc5a1e04d7d5e7bdc45fcbdaea8c41);
#
#
#         var popup_d1431aafa647d6097561b169d18b6bf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1c694f2be07e315b6944f3da56a2119 = $(`&lt;div id=&quot;html_f1c694f2be07e315b6944f3da56a2119&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/1983315941&lt;/div&gt;`)[0];
#                 popup_d1431aafa647d6097561b169d18b6bf1.setContent(html_f1c694f2be07e315b6944f3da56a2119);
#
#
#
#         marker_c9a56d1cbda89f86ee95b6ee433e4dc7.bindPopup(popup_d1431aafa647d6097561b169d18b6bf1)
#         ;
#
#
#
#
#             marker_c9a56d1cbda89f86ee95b6ee433e4dc7.bindTooltip(
#                 `&lt;div&gt;
#                      바다다
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f196dabd63cd6e8016e81771d74f2c98 = L.marker(
#                 [33.24959557, 126.5676211],
#                 {}
#             ).addTo(map_67dc5a1e04d7d5e7bdc45fcbdaea8c41);
#
#
#         var popup_2de8edb90de0acd5ce654d355c0f1a01 = L.popup({&quot;maxWidth&qu

# %%
# 4구역 - 제주동부
jeju4 = ['조천읍', '구좌읍', '남원읍', '표선면', '성산읍', '구좌읍', '우도면']

# 관광지
jeju4_tour_df = distribution("tour_region.csv",
                            "jeju4_tour_region.csv",
                            jeju4)

# 카페/기념품
jeju4_cf_souv_df = distribution("tour_cafe_souvenir.csv",
                       "jeju4_cafe_souvenir.csv",
                       jeju4)

# 음식점
jeju4_restr_df = distribution("tour_restaurant.csv",
                       "jeju4_restaurant.csv",
                       jeju4)

# %%
make_map.make_map(jeju4_tour_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfef2dcf9c5f3b6a3bf839d9594e87c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfef2dcf9c5f3b6a3bf839d9594e87c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfef2dcf9c5f3b6a3bf839d9594e87c3 = L.map(
#                 &quot;map_bfef2dcf9c5f3b6a3bf839d9594e87c3&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fb2010de659818bf3fd5dc3376c485a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_5fb2010de659818bf3fd5dc3376c485a.addTo(map_bfef2dcf9c5f3b6a3bf839d9594e87c3);
#
#             var tile_layer_6d463a8d7e730eebf84edc87614b2c97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_fe73f7518703ca63317cb3e59fd4df3a = new L.Control.MiniMap(
#                 tile_layer_6d463a8d7e730eebf84edc87614b2c97,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_bfef2dcf9c5f3b6a3bf839d9594e87c3.addControl(mini_map_fe73f7518703ca63317cb3e59fd4df3a);
#
#
#             var marker_c043fe78d8a8cc5d9cccaeb282a7c672 = L.marker(
#                 [33.43257409, 126.693832],
#                 {}
#             ).addTo(map_bfef2dcf9c5f3b6a3bf839d9594e87c3);
#
#
#         var popup_d882e82ec0b0f7b26fe89cfea643218c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f7eb974369da6afe59fabce4c2f998a = $(`&lt;div id=&quot;html_7f7eb974369da6afe59fabce4c2f998a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/21348535&lt;/div&gt;`)[0];
#                 popup_d882e82ec0b0f7b26fe89cfea643218c.setContent(html_7f7eb974369da6afe59fabce4c2f998a);
#
#
#
#         marker_c043fe78d8a8cc5d9cccaeb282a7c672.bindPopup(popup_d882e82ec0b0f7b26fe89cfea643218c)
#         ;
#
#
#
#
#             marker_c043fe78d8a8cc5d9cccaeb282a7c672.bindTooltip(
#                 `&lt;div&gt;
#                      산굼부리
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec87dd75421edb92aa24ed0a72c1894f = L.marker(
#                 [33.44821824, 126.6590636],
#                 {}
#             ).addTo(map_bfef2dcf9c5f3b6a3bf839d9594e87c3);
#
#
#         var popup_80a1140e81e2c11d31227ca76e90dff5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1487b46cb863e659a911b8dd132a79c4 = $(`&lt;div id=&quot;html_1487b46cb863e659a911b8dd132a79c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/13322621&lt;/div&gt;`)[0];
#                 popup_80a1140e81e2c11d31227ca76e90dff5.setContent(html_1487b46cb863e659a911b8dd132a79c4);
#
#
#
#         marker_ec87dd75421edb92aa24ed0a72c1894f.bindPopup(popup_80a1140e81e2c11d31227ca76e90dff5)
#         ;
#
#
#
#
#             marker_ec87dd75421edb92aa24ed0a72c1894f.bindTooltip(
#                 `&lt;div&gt;
#                      제주돌문화공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a9056bc0d230e0ee8135324f0c980879 = L.marker(
#                 [33.46516535, 126.6595954],
#                 {}
#             ).addTo(map_bfef2dcf9c5f3b6a3bf839d9594e87c3);
#
#
#         var popup_6fc85e399d8903e310d2aedf4d498222 = L.popup({&quot;maxWidth&quot;:

# %%
make_map.make_map(jeju4_cf_souv_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1b13af4a91e09ce32ed3e7a6e7eee3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1b13af4a91e09ce32ed3e7a6e7eee3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1b13af4a91e09ce32ed3e7a6e7eee3a = L.map(
#                 &quot;map_a1b13af4a91e09ce32ed3e7a6e7eee3a&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_391635293d8629a47c4bb756fe878588 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_391635293d8629a47c4bb756fe878588.addTo(map_a1b13af4a91e09ce32ed3e7a6e7eee3a);
#
#             var tile_layer_4b2ee9435ac3627f22aac8a8a4bcaa7d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_001a183435af3ebac690419ac61b20b8 = new L.Control.MiniMap(
#                 tile_layer_4b2ee9435ac3627f22aac8a8a4bcaa7d,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_a1b13af4a91e09ce32ed3e7a6e7eee3a.addControl(mini_map_001a183435af3ebac690419ac61b20b8);
#
#
#             var marker_62a1996b85ad1f6b644be6d4b6d4e8dd = L.marker(
#                 [33.48792319, 126.7124676],
#                 {}
#             ).addTo(map_a1b13af4a91e09ce32ed3e7a6e7eee3a);
#
#
#         var popup_e7ac4061c488d3fd8a5257880801b39c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7593c8405e359382d0bc4266258a0df7 = $(`&lt;div id=&quot;html_7593c8405e359382d0bc4266258a0df7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/247665892&lt;/div&gt;`)[0];
#                 popup_e7ac4061c488d3fd8a5257880801b39c.setContent(html_7593c8405e359382d0bc4266258a0df7);
#
#
#
#         marker_62a1996b85ad1f6b644be6d4b6d4e8dd.bindPopup(popup_e7ac4061c488d3fd8a5257880801b39c)
#         ;
#
#
#
#
#             marker_62a1996b85ad1f6b644be6d4b6d4e8dd.bindTooltip(
#                 `&lt;div&gt;
#                      종종제주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9a0be2b38db6110b6cc3bb69ca95d22 = L.marker(
#                 [33.53222308, 126.6186003],
#                 {}
#             ).addTo(map_a1b13af4a91e09ce32ed3e7a6e7eee3a);
#
#
#         var popup_87c1a240c671c83faf410ad250805648 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d233390214f2820aadf5fa6bd7e41df1 = $(`&lt;div id=&quot;html_d233390214f2820aadf5fa6bd7e41df1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/15751877&lt;/div&gt;`)[0];
#                 popup_87c1a240c671c83faf410ad250805648.setContent(html_d233390214f2820aadf5fa6bd7e41df1);
#
#
#
#         marker_e9a0be2b38db6110b6cc3bb69ca95d22.bindPopup(popup_87c1a240c671c83faf410ad250805648)
#         ;
#
#
#
#
#             marker_e9a0be2b38db6110b6cc3bb69ca95d22.bindTooltip(
#                 `&lt;div&gt;
#                      덕인당보리빵
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_65efc02c086cdbe5491a9f8069491ca9 = L.marker(
#                 [33.54374906, 126.6630636],
#                 {}
#             ).addTo(map_a1b13af4a91e09ce32ed3e7a6e7eee3a);
#
#
#         var popup_9db2b52b0cabb78ba75cdff6e1dda284 = L.popup({&quot;maxWidth&quot;:

# %%
make_map.make_map(jeju4_restr_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b1aeb243d54830dcb78ca53b42f671c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b1aeb243d54830dcb78ca53b42f671c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b1aeb243d54830dcb78ca53b42f671c = L.map(
#                 &quot;map_0b1aeb243d54830dcb78ca53b42f671c&quot;,
#                 {
#                     center: [33.5101562, 126.4861157],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efd618e1451ac3d1d0b4d466a292f35f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_efd618e1451ac3d1d0b4d466a292f35f.addTo(map_0b1aeb243d54830dcb78ca53b42f671c);
#
#             var tile_layer_285e4b548f9bb186910ccf1031ef73b4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_8a4b565a1eb1f65f428614cd58d3a7ab = new L.Control.MiniMap(
#                 tile_layer_285e4b548f9bb186910ccf1031ef73b4,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_0b1aeb243d54830dcb78ca53b42f671c.addControl(mini_map_8a4b565a1eb1f65f428614cd58d3a7ab);
#
#
#             var marker_43be16c503bfdf8e078d5791e8dbc3dd = L.marker(
#                 [33.43692114, 126.6731393],
#                 {}
#             ).addTo(map_0b1aeb243d54830dcb78ca53b42f671c);
#
#
#         var popup_ac5f8e197e74dd2f8ec9c81681cec9e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9075d34f52c9235fc90d551e26dbafcb = $(`&lt;div id=&quot;html_9075d34f52c9235fc90d551e26dbafcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/471417273&lt;/div&gt;`)[0];
#                 popup_ac5f8e197e74dd2f8ec9c81681cec9e9.setContent(html_9075d34f52c9235fc90d551e26dbafcb);
#
#
#
#         marker_43be16c503bfdf8e078d5791e8dbc3dd.bindPopup(popup_ac5f8e197e74dd2f8ec9c81681cec9e9)
#         ;
#
#
#
#
#             marker_43be16c503bfdf8e078d5791e8dbc3dd.bindTooltip(
#                 `&lt;div&gt;
#                      램앤블랙
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7ddd189d0dc0f07de1efd6366e9e670 = L.marker(
#                 [33.43583724, 126.6792945],
#                 {}
#             ).addTo(map_0b1aeb243d54830dcb78ca53b42f671c);
#
#
#         var popup_dd127164baffde01e3453e27ab073910 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a210a51e8c5590399568421d8d6c7be9 = $(`&lt;div id=&quot;html_a210a51e8c5590399568421d8d6c7be9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/1492579639&lt;/div&gt;`)[0];
#                 popup_dd127164baffde01e3453e27ab073910.setContent(html_a210a51e8c5590399568421d8d6c7be9);
#
#
#
#         marker_f7ddd189d0dc0f07de1efd6366e9e670.bindPopup(popup_dd127164baffde01e3453e27ab073910)
#         ;
#
#
#
#
#             marker_f7ddd189d0dc0f07de1efd6366e9e670.bindTooltip(
#                 `&lt;div&gt;
#                      우동카덴
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9113fb6b6b0a7c471e7878641d19aabe = L.marker(
#                 [33.42372662, 126.6750575],
#                 {}
#             ).addTo(map_0b1aeb243d54830dcb78ca53b42f671c);
#
#
#         var popup_d8914fc93b64d80d3441b299de15f967 = L.popup({&quot;maxWidth&quot;:
